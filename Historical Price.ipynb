# %%
import history

# %% [markdown]
# # Get Prices from 0001 to 9999

# %%
# %%time

for i in range(1, 10000):
    ticker = "{}.HK".format(str(i).zfill(4))
    prices = history.get_prices(ticker)
# Out:
# Fetching 0004.HK from yfinance...
# Fetching 0005.HK from yfinance...
# Fetching 0006.HK from yfinance...
# Fetching 0007.HK from yfinance...
# Fetching 0008.HK from yfinance...
# Fetching 0009.HK from yfinance...
# Fetching 0010.HK from yfinance...
# Fetching 0011.HK from yfinance...
# Fetching 0012.HK from yfinance...
# Fetching 0013.HK from yfinance...
# - 0013.HK: 1d data not available for startTime=-2208988800 and endTime=1591502993. Only 100 years worth of day granularity data are allowed to be fetched per request.
# Fetching 0014.HK from yfinance...
# Fetching 0015.HK from yfinance...
# Fetching 0016.HK from yfinance...
# Fetching 0017.HK from yfinance...
# Fetching 0018.HK from yfinance...
# Fetching 0019.HK from yfinance...
# Fetching 0020.HK from yfinance...
# Fetching 0021.HK from yfinance...
# Fetching 0022.HK from yfinance...
# Fetching 0023.HK from yfinance...
# Fetching 0024.HK from yfinance...
# Fetching 0025.HK from yfinance...
# Fetching 0026.HK from yfinance...
# ...

# %% [markdown]
# # Get Price from Target Stock

# %%
# %%time
ticker = "0013.HK"
prices = history.get_prices(ticker)
prices.index
# Out:
# CPU times: user 4.09 ms, sys: 9.24 ms, total: 13.3 ms
# Wall time: 8.95 ms
# DatetimeIndex([], dtype='datetime64[ns]', name='Date', freq=None)
