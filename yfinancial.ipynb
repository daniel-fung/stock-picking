# %%
import pandas as pd
import yfinance as yf

# %%
data_dir = "data"

# %%
#ticker = "0001.HK"
ticker = "AAPL"
data = yf.Ticker(ticker)
file_name = f"{data_dir}/{ticker}.csv"
data.history(period="max").to_csv(file_name, index=False)
data.history(period="max").tail(5)
# Out:
#               Open    High     Low   Close     Volume  Dividends  Stock Splits
# Date
# 2020-03-16  241.95  259.08  240.00  242.21   80605900        0.0           0.0
# 2020-03-17  247.51  257.61  238.40  252.86   81014000        0.0           0.0
# 2020-03-18  239.77  250.00  237.12  246.67   75058400        0.0           0.0
# 2020-03-19  247.39  252.84  242.61  244.78   67964300        0.0           0.0
# 2020-03-20  247.18  251.83  228.00  229.24  100257000        0.0           0.0

# %%
data.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
#yf.download("0700.HK")
